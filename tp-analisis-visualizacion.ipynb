# %% [markdown]
# ## Análisis y Visualización - Mentoría

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv('../dataset/data_review.csv')

# %% [markdown]
# ### Conociendo como está formado el dataset

# %%
# Poder investigar rápidamente el tipo de datos con los que vamos a trabajar
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# rating    100000 non-null int64
# title     99999 non-null object
# review    100000 non-null object
# target    93225 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
# Tomamos contacto con los primeros datos.
dt.head()
# Out:
#    rating                                   title  \
# 0       5  .............Am I in Midgard anymore ?
# 1       1   Zip wax new formula is just horrible.
# 2       5                 Apatow's Depth Triumphs
# 3       1                             Dream of C.
# 4       1                         it doesnt suck.
#
#                                               review  target
# 0  I was so disappointed to find she has not writ...     1.0
# 1  I've been using zip wax for many years. It was...     0.0
# 2  I am a stand-up fanatic. I enjoy the alternati...     1.0
# 3  It is to bad such talented illustrations are i...     0.0
# 4  this product doesnt vaccum out the air I was d...     0.0

# %% [markdown]
# ## Informe

# %% [markdown]
# ### Relación entre el puntaje y la clase 'Target'

# %% [markdown]
# ### *Conclusiones a partir de un dataset incompleto*
#
# Algo interesante que sucedió al comienzo de la investigación fue que, por un malentendido, ambos empezamos a trabajar con un dataset que era en realidad un back-up del original y no el destinado para la redacción de este informe. En particular, no tenía ninguna columna target y estaba bien balanceado entre todos los puntajes del 1 al 5. No fue posible encontrar correlaciones llamativas entre las clases de datos con los que contábamos, aunque una hipótesis posible inicial fue imaginarse si había alguna relación entre el largo de una review y el puntaje que se le dio al producto. Rápidamente se pudo descartar esta teoría calculando un par de estadísticos y no se pudo determinar que una review larga indicara un puntaje alto o bajo, ni viceversa (una review corta tampoco iría necesariamente de la mano con un puntaje particularmente alto o bajo).

# %% [markdown]
# Esto se condice con la realidad que conocemos, si pensamos en la animosidad que una mala experiencia con un producto nos puede generar como clientes, y que ese sentimiento muchas veces se traduce en una review larga y detallada sobre todos los defectos que le pudimos encontrar.

# %% [markdown]
# ### Caso especial: Puntaje 3
#
# Analizando la naturaleza de los datos de la columna 'target', surge una primera duda: ¿cómo clasificaríamos una review con un puntaje de 3 sobre 5? ¿Le daríamos un 1 como buena review o 0 y tomarla como negativa?
# El dataset inicial no tiene ningún valor numérico asignado para un rating de 3:

# %%
dt[dt['rating']==3]
# Out:
#        rating                                              title  \
# 17          3                                No Good Multiplayer
# 27          3                 Fast and Fun Start To A New Series
# 29          3                                      isnt the best
# 55          3                     Packed full of laughs & music!
# 59          3                              Missing A Key Element
# 62          3                         Good Book - needs revising
# 87          3                                 all we have so far
# 100         3                                         Oh well...
# 124         3                               Larger than expected
# 159         3            Good fun, but not his best Burglar IMHO
# 176         3                               WOW that went quick.
# 178         3                                  Meg Hentges music
# 218         3                        Quick. Concise. Informative
# 219         3                                        DVD vs. VHS
# 222         3                       Not a story worthy of an OVA
# 250         3                     The sequel was actually better
# 260         3                                        Good to use
# 267         3                   Just an ordinary accounting book
# 284         3   Brilliant Art, Great Concept, Muddled Characters
# 296         3                         Funny, but a little boring
# 298         3                     Sesame Street Meets Fairy Tale
# 315         3                        not a Veritas, but works ok
# 329         3                                   very disapointed
# 337         3                  I've seen better Star Wars novels
# 351         3                 Better solo violin and cello exist
# 362         3  I Still Can't Believe the Pats did it---this v...
# 390         3                  Horror Classics Vol. 2 - ID#12249
# 406         3                               ...limited review...
# 413         3                Imperative for Lutyens Fans, but...
# 427         3                                  Very Good but....
# ...       ...                                                ...
# 99627       3                  Graphically Okay, But not as fun!
# 99639       3                                        Yeah! Rock!
# 99641       3                                        merely "OK"
# 99671       3                           Some great Daffy moments
# 99703       3                    Roxana, I wanted more from you!
# 99732       3                                    Not as expected
# 99746       3                                        More change
# 99754       3                                       Not a Primer
# 99767       3                                         Great fun!
# 99769       3                                   Overlooked Dylan
# 99789       3      A great book if you already know the material
# 99793       3                            Interesting...in a way.
# 99797       3                                      Mildy Amusing
# 99807       3                                             Victim
# 99809       3  Tiny phone for tiny hands (i.e. men need not a...
# 99818       3                   Good, but can not read SDHC card
# 99844       3     Interesting, Readable, But Far From Compelling
# 99846       3                               Picture is deceiving
# 99881       3                             Large Cardboard Blocks
# 99899       3                                       Poor Quality
# 99903       3         Nice blender, but I don't like the chopper
# 99908       3                          Awkward and Uncomfortable
# 99923       3                  good for a first bible dictionary
# 99927       3                                          Flip out!
# 99961       3                                       disappointed
# 99975       3           It's OK- if you just take it in good fun
# 99978       3            [based upon samples] the late '60s band
# 99979       3                                                 ok
# 99984       3                                            Just Ok
# 99996       3  This book has everything to become a 1000 star...
#
#                                                   review  target
# 17     Long knowing that I've played Half-Life becaus...     NaN
# 27     Maximum Ride is the title of the book and also...     NaN
# 29     I almost bought this c.d when I stopped to lis...     NaN
# 55     This movie was surprisingly entertaining. Even...     NaN
# 59     Don't get me wrong, this is a charming story o...     NaN
# 62     The concept taught in this book (of the method...     NaN
# 87     Unfortunately not much has been written about ...     NaN
# 100    B.B. King and Eric Clapton are both up there a...     NaN
# 124    I was expecting a XL but it turns out that dic...     NaN
# 159    While Lawrence Block's Burglar series is a bit...     NaN
# 176    I am a huge fan of both the Anita Blake and Me...     NaN
# 178    I found my first Meg Hentges CD at Dimple for ...     NaN
# 218    After reading this novel for my Enlgish class,...     NaN
# 219    How is the DVD different that the VHS Director...     NaN
# 222    I was hoping the quality of the anime would be...     NaN
# 250    This book is a solid "okay". The Volume 2, how...     NaN
# 260    This keyboard is very useful for the leftys. V...     NaN
# 267    The book is overall quite good as an introduct...     NaN
# 284    Templesmith is a master artist and conceptuali...     NaN
# 296    Abby's Unvalentine shows that Abby isn't ready...     NaN
# 298    "Silly Storytime" is a journey to a fairy-tale...     NaN
# 315    This is not a Veritas or TiteMark quality tool...     NaN
# 329    Usually when you see "directors cut" one think...     NaN
# 337    While I enjoy the continuing story of Luke's f...     NaN
# 351    I do not know why DG put Maisky and Mintz on t...     NaN
# 362    OK you gotta love it because it recaps the ama...     NaN
# 390    Four movies on one disc.Horror Classics Vol. 2...     NaN
# 406    I have only had the WR300 for a couple of mont...     NaN
# 413    A must have for Lutyemns fans, but not the mea...     NaN
# 427    An excellent book to read, but seemed a tad to...     NaN
# ...                                                  ...     ...
# 99627  Robots is pretty much a port of the GBA game b...     NaN
# 99639  This is a great album! It has such classics as...     NaN
# 99641  The colors and illustration in this book are f...     NaN
# 99671  If you love Looney Tunes, then like me, you pr...     NaN
# 99703  Although well written, this story of an "ordin...     NaN
# 99732  I had to watch this movie twice to figure out ...     NaN
# 99746  Yep, I love the Plan, too. It's not really tha...     NaN
# 99754  When you learned to read English (e.g. Dick an...     NaN
# 99767  My son likes doing puzzles, and this is great ...     NaN
# 99769  Look is this Zimmy's best album? Far from it.....     NaN
# 99789  This is definitely one of those books that get...     NaN
# 99793  The guys who thought this up were really out t...     NaN
# 99797  Being a child of the 80's I enjoyed the soundt...     NaN
# 99807  Although the writing is excellent, I couldnt g...     NaN
# 99809  I'm not going to bore you with the many featur...     NaN
# 99818  I was sad to find I can not read my SDHC (too ...     NaN
# 99844  Interesting, highly readable, but ultimately p...     NaN
# 99846  This item's picture appears to be a brushed st...     NaN
# 99881  These blocks (40) come in a flat package and t...     NaN
# 99899  I ordered this 'used' from one of Amazon's dea...     NaN
# 99903  The stick blender is WONDERFUL.I just love mak...     NaN
# 99908  This sprayer is not for big jobs. If you are l...     NaN
# 99923  Not what I expected and it looked used and I t...     NaN
# 99927  This is a good book.Sacks is a good writer, he...     NaN
# 99961  I purchased this product to clean the grout in...     NaN
# 99975  At a school dance was the first time I ever he...     NaN
# 99978  Songlist looks inviting but no vocals followin...     NaN
# 99979  According to the seller the book i purchased w...     NaN
# 99984  Not bad for the price however a few flaws in t...     NaN
# 99996  however, it is indeed too general, too much to...     NaN
#
# [6775 rows x 4 columns]

# %% [markdown]
# Para un caso tan ambiguo como éste, podemos guiarnos a partir del resto de los datos, es decir, en qué contexto se encuentra.
# Al evaluar la proporción de cada puntaje dentro del dataset, asumiendo que éste representa adecuadamente la población total, podemos observar que es mayor la cantidad de reviews positivas (4 y 5) que negativas (2 y 1).

# %%
plt.hist(x=dt["rating"], align='mid', label='Rating')
# NAHUEL: no sé por qué me queda el gráfico así (no bien alineado, no se que estaré haciendo mal pero siempre me pasa)
plt.title("Proporción de cada puntaje")
plt.show()

# %% [markdown]
# Podemos interpretar este hecho como que la persona promedio tiende a ser más **generosa** al ratear productos, y esto nos conduce a pensar que un 3 no representa un cliente demasiado satisfecho. Es por esto que a estos valores NaN le asignamos un valor de '0' (review negativa) en la columna 'target'.

# %%
dt[dt['rating']==3] = dt[dt['rating']==3].fillna(0)
sub_dt = dt[['rating', 'target']]
